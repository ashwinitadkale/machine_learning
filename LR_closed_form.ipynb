# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\ashwi\Desktop\machine_learning\study_time_vs_score.csv")

# %%
class LinearRegressionClosed:
    def __init__(self):
        self.coef_=None
        self.intercept_=0.0
    def fit(self,X,y):
        X=np.array(X)
        y=np.array(y)
        ones=np.ones((X.shape[0],1))
        X_b=np.hstack((ones,X))

        theta=np.linalg.inv(X_b.T @ X_b) @ X_b.T @ y

        self.intercept_=theta[0]
        self.coef_=theta[1:]
    def predict(self,X):
        X=np.array(X)

        return X @ self.coef_ + self.intercept_

# %%
X = [[1], [2], [3], [4]]
y = [2, 4, 6, 8]

model = LinearRegressionClosed()
model.fit(X, y)

print("Intercept:", model.intercept_)
print("Coefficients:", model.coef_)

pred = model.predict([[5]])
print("Prediction for 5:", pred)
# Out:
# Intercept: 0.0
# Coefficients: [2.]
# Prediction for 5: [10.]

# %%
#pseudo-inverse used when matrix cant be inversed
theta = np.linalg.pinv(X_b) @ y
