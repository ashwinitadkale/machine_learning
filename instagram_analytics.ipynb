# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %%
df=pd.read_csv(r"C:\Users\ashwi\Desktop\machine_learning\Instagram_Analytics.csv")

# %%
df.head()
# Out:
#      post_id  account_id account_type  follower_count media_type  \
# 0  IG0000001           7        brand            3551       reel
# 1  IG0000002          20      creator           31095      image
# 2  IG0000003          15        brand            8167       reel
# 3  IG0000004          11      creator            9044   carousel
# 4  IG0000005           8      creator           15986       reel
#
#   content_category traffic_source  has_call_to_action        post_datetime  \
# 0       Technology      Home Feed                   1  2024-11-30 06:00:00
# 1          Fitness       Hashtags                   1  2025-08-15 15:00:00
# 2           Beauty     Reels Feed                   0  2025-09-11 16:00:00
# 3            Music       External                   0  2025-09-18 03:00:00
# 4       Technology        Profile                   0  2025-03-21 09:00:00
#
#     post_date  ...  comments shares  saves  reach  impressions  \
# ...

# %%
df.shape
# Out:
# (29999, 23)

# %%
df.describe()
# Out:
#          account_id  follower_count  has_call_to_action     post_hour  \
# count  29999.000000    29999.000000        29999.000000  29999.000000
# mean      10.567819    10278.305477            0.348778     11.499417
# std        5.763952     6691.862669            0.476592      6.900587
# min        1.000000     3083.000000            0.000000      0.000000
# 25%        6.000000     5824.000000            0.000000      6.000000
# 50%       11.000000     9044.000000            0.000000     12.000000
# 75%       16.000000    10739.000000            1.000000     17.000000
# max       20.000000    31095.000000            1.000000     23.000000
#
#               likes      comments        shares         saves         reach  \
# count  29999.000000  29999.000000  29999.000000  29999.000000  29999.000000
# mean     287.653588      8.521917     14.426614     42.517284   6272.475449
# std      317.647682     10.116505     16.420899     47.808844   4985.877059
# ...

# %%
df.columns
# Out:
# Index(['post_id', 'account_id', 'account_type', 'follower_count', 'media_type',
#        'content_category', 'traffic_source', 'has_call_to_action',
#        'post_datetime', 'post_date', 'post_hour', 'day_of_week', 'likes',
#        'comments', 'shares', 'saves', 'reach', 'impressions',
#        'engagement_rate', 'followers_gained', 'caption_length',
#        'hashtags_count', 'performance_bucket_label'],
#       dtype='str')

# %%
df.drop(columns=['post_id','account_id','post_datetime','post_date'])
# Out:
#       account_type  follower_count media_type content_category traffic_source  \
# 0            brand            3551       reel       Technology      Home Feed
# 1          creator           31095      image          Fitness       Hashtags
# 2            brand            8167       reel           Beauty     Reels Feed
# 3          creator            9044   carousel            Music       External
# 4          creator           15986       reel       Technology        Profile
# ...            ...             ...        ...              ...            ...
# 29994        brand           10739   carousel           Travel     Reels Feed
# 29995        brand           10018      image           Beauty       Hashtags
# 29996      creator            7486      image      Photography        Explore
# 29997      creator           10034   carousel       Technology        Explore
# 29998      creator            6916      image       Technology        Explore
#
# ...

# %%
cats_col=['account_type','media_type','content_category','traffic_source','day_of_week','performance_bucket_label']

# %%
le=LabelEncoder()
for col in cats_col:
    df[col]=le.fit_transform(df[col])
X=df.drop(columns=['engagement_rate', 'performance_bucket_label'])
y=df['engagement_rate']

# %%
from xgboost import XGBRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
model = XGBRegressor(
    n_estimators=300,
    learning_rate=0.05,
    max_depth=6
)

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\ashwi\Desktop\machine_learning\.venv\Lib\site-packages\xgboost\data.py:408, in pandas_feature_info(data, meta, feature_names, feature_types, enable_categorical)
#     407 try:
# --> 408     new_feature_types.append(_pandas_dtype_mapper[dtype.name])
#     409 except KeyError:
#
# KeyError: 'str'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 model.fit(X_train, y_train)
#
# File c:\Users\ashwi\Desktop\machine_learning\.venv\Lib\site-packages\xgboost\core.py:751, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     749 for k, arg in zip(sig.parameters, args):
#     750     kwargs[k] = arg
# --> 751 return func(**kwargs)
#
# ...
